# %%
# libraries
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import pandas as pd

# %%
df = pd.read_csv('diabetes_prediction_dataset.csv')
df.head(30)
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  80.0             0              1           never  25.19
# 1   Female  54.0             0              0         No Info  27.32
# 2     Male  28.0             0              0           never  27.32
# 3   Female  36.0             0              0         current  23.45
# 4     Male  76.0             1              1         current  20.14
# 5   Female  20.0             0              0           never  27.32
# 6   Female  44.0             0              0           never  19.31
# 7   Female  79.0             0              0         No Info  23.86
# 8     Male  42.0             0              0           never  33.64
# 9   Female  32.0             0              0           never  27.32
# 10  Female  53.0             0              0           never  27.32
# 11  Female  54.0             0              0          former  54.70
# 12  Female  78.0             0              0          former  36.05
# ...

# %%
classifier = SVC()
pd.options.mode.copy_on_write = True

train_data = pd.read_csv('diabetes_prediction_dataset.csv')

X_train = train_data[['gender', 'age', 'heart_disease', 'hypertension']]
X_train['gender'] = X_train.gender.apply(lambda x: 1.0 if x == 'Male' else 2.0).copy()
X_train = X_train.fillna(0)
y_train = train_data['diabetes']
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# train data
X = X_train.fillna(0)
X = X_train.to_numpy()
y = y_train

# test data
y = y.to_numpy()
X_test = X_test.fillna(0)
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

classifier.fit(X,y)
predicts = classifier.predict(X_test)

print(classification_report(y_test, predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96     18292
#            1       0.00      0.00      0.00      1708
#
#     accuracy                           0.91     20000
#    macro avg       0.46      0.50      0.48     20000
# weighted avg       0.84      0.91      0.87     20000
# c:\Users\Susanne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Susanne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
